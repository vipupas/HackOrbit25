# %%
print("YOLO is using device:", model.device)
# Out:
# YOLO is using device: cuda:0

# %%
from ultralytics import YOLO
import cv2
import torch
import numpy as np

# Check GPU
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))

# Load YOLO model and move to GPU
model = YOLO("yolov8n.pt")
model.to("cuda")
print("YOLO is using device:", model.device)

# Paths to your 3 videos
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

# Open video captures
caps = [cv2.VideoCapture(path) for path in video_paths]

# Read until any one video ends
while True:
    frames = []
    for cap in caps:
        ret, frame = cap.read()
        if not ret:
            break
        # Run YOLO detection on frame
        results = model(frame, conf=0.3)
        # Plot annotations
        annotated_frame = results[0].plot()
        frames.append(annotated_frame)

    if len(frames) != len(caps):
        break  # Stop if any video ended

    # Resize frames to same height
    heights = [f.shape[0] for f in frames]
    min_height = min(heights)
    resized_frames = [cv2.resize(f, (int(f.shape[1] * min_height / f.shape[0]), min_height)) for f in frames]

    # Combine horizontally
    combined_frame = np.hstack(resized_frames)

    # Show in one window
    cv2.imshow("3-Way Junction Vehicle Detection", combined_frame)

    # Stop with 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release videos
for cap in caps:
    cap.release()
cv2.destroyAllWindows()
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU
# YOLO is using device: cuda:0
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 4.5ms preprocess, 25.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.2ms
# Speed: 3.3ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.6ms
# Speed: 3.6ms preprocess, 20.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# Speed: 2.4ms preprocess, 19.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# Speed: 2.9ms preprocess, 19.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 19.2ms
# Speed: 2.5ms preprocess, 19.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.0ms
# ...

# %%
from ultralytics import YOLO
import cv2
import torch
import numpy as np

# Check GPU
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))

# Load YOLO model and move to GPU
model = YOLO("yolov8n.pt")
model.to("cuda")
print("YOLO is using device:", model.device)

# Paths to your 3 videos
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

caps = [cv2.VideoCapture(path) for path in video_paths]

# Read until any one video ends
while True:
    frames = []
    ended = False
    for idx, cap in enumerate(caps):
        ret, frame = cap.read()
        if not ret:
            ended = True
            break

        # YOLO detection
        results = model(frame, conf=0.3)
        annotated_frame = results[0].plot()

        # Add camera label
        cv2.putText(annotated_frame, f"Cam {idx + 1}", (20, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)

        frames.append(annotated_frame)

    if ended or len(frames) != len(caps):
        break

    # Make all frames same size (height = 480)
    target_height = 480
    resized_frames = [
        cv2.resize(f, (int(f.shape[1] * target_height / f.shape[0]), target_height))
        for f in frames
    ]

    # Prepare grid
    blank = np.zeros_like(resized_frames[0])

    # If you have fewer than 4 frames, fill with blank
    while len(resized_frames) < 4:
        resized_frames.append(blank)

    # First row
    row1 = np.hstack((resized_frames[0], resized_frames[1]))
    # Second row
    row2 = np.hstack((resized_frames[2], resized_frames[3]))
    # Stack rows vertically
    grid_frame = np.vstack((row1, row2))

    # Show
    cv2.imshow("3-Way Junction Vehicle Detection (Grid View)", grid_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release
for cap in caps:
    cap.release()
cv2.destroyAllWindows()
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU
# YOLO is using device: cuda:0
#
# 0: 384x640 (no detections), 25.8ms
# Speed: 6.4ms preprocess, 25.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.7ms
# Speed: 3.7ms preprocess, 21.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 24.2ms
# Speed: 3.6ms preprocess, 24.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 2.7ms preprocess, 18.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 5.2ms preprocess, 18.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 18.2ms
# Speed: 2.8ms preprocess, 18.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.9ms
# ...

# %%
# To draw shape in which the vehicle would be counted 


import cv2

# Video paths
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

roi_polygons = []

# Global points
points = []

def draw_polygon(event, x, y, flags, param):
    global points, frame_copy

    if event == cv2.EVENT_LBUTTONDOWN:
        points.append((x, y))
        frame_copy = frame.copy()
        for p in points:
            cv2.circle(frame_copy, p, 5, (0, 0, 255), -1)
        if len(points) > 1:
            cv2.polylines(frame_copy, [np.array(points)], isClosed=False, color=(0, 255, 0), thickness=2)

for path in video_paths:
    cap = cv2.VideoCapture(path)

    # Skip to 20 sec
    cap.set(cv2.CAP_PROP_POS_MSEC, 20000)

    ret, frame = cap.read()
    if not ret:
        print(f"Could not read from {path}")
        cap.release()
        continue

    frame_copy = frame.copy()
    points = []

    cv2.namedWindow("Draw Polygon ROI")
    cv2.setMouseCallback("Draw Polygon ROI", draw_polygon)

    while True:
        cv2.imshow("Draw Polygon ROI", frame_copy)
        key = cv2.waitKey(1) & 0xFF

        if key == ord("r"):
            frame_copy = frame.copy()
            points = []
        elif key == ord("s"):
            if len(points) >= 3:
                roi_polygons.append(points.copy())
                print(f"Saved polygon: {points}")
                break
            else:
                print("Select at least 3 points!")
        elif key == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()

print("All ROI polygons:", roi_polygons)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27, in draw_polygon(event, x, y, flags, param)
#      25     cv2.circle(frame_copy, p, 5, (0, 0, 255), -1)
#      26 if len(points) > 1:
# ---> 27     cv2.polylines(frame_copy, [np.array(points)], isClosed=False, color=(0, 255, 0), thickness=2)
#
# NameError: name 'np' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27, in draw_polygon(event, x, y, flags, param)
#      25     cv2.circle(frame_copy, p, 5, (0, 0, 255), -1)
#      26 if len(points) > 1:
# ---> 27     cv2.polylines(frame_copy, [np.array(points)], isClosed=False, color=(0, 255, 0), thickness=2)
#
# NameError: name 'np' is not defined
# ---------------------------------------------------------------------------
# ...

# %%
from ultralytics import YOLO
import cv2
import torch
import numpy as np

# Check GPU
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))

# Load YOLO model and move to GPU
model = YOLO("yolov8n.pt")
model.to("cuda")
print("YOLO is using device:", model.device)

# Video paths
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

# ROI polygons (from your points)
roi_polygons = [
    [(228, 713), (511, 34), (565, 46), (1250, 654)],
    [(283, 718), (557, 95), (644, 89), (1078, 689)],
    [(508, 715), (677, 71), (732, 71), (1101, 690)]
]

# Vehicle classes to count
vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck

# Open captures
caps = [cv2.VideoCapture(path) for path in video_paths]

while True:
    frames = []
    vehicle_counts = []

    for i, cap in enumerate(caps):
        ret, frame = cap.read()
        if not ret:
            break

        # YOLO detection
        results = model(frame, conf=0.3)

        # Get polygon for this video
        polygon_pts = roi_polygons[i]

        count = 0
        for box in results[0].boxes:
            cls_id = int(box.cls)
            if cls_id in vehicle_classes:
                x_min = box.xyxy[0][0].item()
                y_min = box.xyxy[0][1].item()
                x_max = box.xyxy[0][2].item()
                y_max = box.xyxy[0][3].item()

                center_x = (x_min + x_max) / 2
                center_y = (y_min + y_max) / 2

                # Check if center is inside polygon
                inside = cv2.pointPolygonTest(np.array(polygon_pts, dtype=np.int32), (center_x, center_y), False)
                if inside >= 0:
                    count += 1

        # Draw polygon on frame
        cv2.polylines(frame, [np.array(polygon_pts, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=3)

        # Add count text
        cv2.putText(frame, f"Count: {count}", (30, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 4)

        # Draw YOLO boxes
        annotated_frame = results[0].plot()

        # Overlay polygon on annotated frame again
        cv2.polylines(annotated_frame, [np.array(polygon_pts, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=3)

        # Add count text again
        cv2.putText(annotated_frame, f"Count: {count}", (30, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 4)

        frames.append(annotated_frame)
        vehicle_counts.append(count)

    if len(frames) != len(caps):
        break

    
    # Resize to same size (fix target size)
    target_height = 480
    target_width = 640

    resized_frames = [cv2.resize(f, (target_width, target_height)) for f in frames]

    # Combine horizontally
    combined_frame = np.hstack(resized_frames)


    # Show
    cv2.imshow("3-Way Vehicle Count with Polygons", combined_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release
for cap in caps:
    cap.release()
cv2.destroyAllWindows()
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU
# YOLO is using device: cuda:0
#
# 0: 384x640 (no detections), 26.3ms
# Speed: 4.7ms preprocess, 26.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 3.7ms preprocess, 20.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 3.8ms preprocess, 20.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.8ms
# Speed: 5.2ms preprocess, 19.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# Speed: 2.6ms preprocess, 19.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 19.2ms
# Speed: 3.3ms preprocess, 19.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.1ms
# ...

# %%
from ultralytics import YOLO
import cv2
import torch
import numpy as np

# Check GPU
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))

# Load YOLO model and move to GPU
model = YOLO("yolov8n.pt")
model.to("cuda")
print("YOLO is using device:", model.device)

# Video paths
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

# ROI polygons (new updated points)
roi_polygons = [
    [(208, 700), (500, 47), (575, 41), (1271, 660)],  # Cam 1
    [(261, 715), (552, 83), (656, 82), (1056, 706)],  # Cam 2
    [(481, 718), (672, 49), (722, 49), (1142, 713)]   # Cam 3
]


# Vehicle classes
vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck
person_class = 0               # person class

# Open captures
caps = [cv2.VideoCapture(path) for path in video_paths]

while True:
    frames = []

    for i, cap in enumerate(caps):
        ret, frame = cap.read()
        if not ret:
            break

        # YOLO detection
        results = model(frame, conf=0.3)

        polygon_pts = roi_polygons[i]
        count = 0

        for box in results[0].boxes:
            cls_id = int(box.cls)

            if cls_id in vehicle_classes or cls_id == person_class:
                x_min = box.xyxy[0][0].item()
                y_min = box.xyxy[0][1].item()
                x_max = box.xyxy[0][2].item()
                y_max = box.xyxy[0][3].item()

                center_x = (x_min + x_max) / 2
                center_y = (y_min + y_max) / 2

                inside = cv2.pointPolygonTest(np.array(polygon_pts, dtype=np.int32), (center_x, center_y), False)
                if inside >= 0:
                    count += 1

                # Draw bounding box
                cv2.rectangle(frame, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)

                # Assign label
                if cls_id == person_class:
                    label = "motorcycle"  # Change label to motorcycle
                else:
                    label = model.names[cls_id]

                # Draw label
                cv2.putText(frame, label, (int(x_min), int(y_min) - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

        # Draw polygon
        cv2.polylines(frame, [np.array(polygon_pts, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=3)

        # Annotate count
        cv2.putText(frame, f"Count: {count}", (30, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255), 4)

        frames.append(frame)

    if len(frames) != len(caps):
        break

    # Resize to same size
    target_height = 480
    target_width = 640
    resized_frames = [cv2.resize(f, (target_width, target_height)) for f in frames]

    # Combine
    combined_frame = np.hstack(resized_frames)

    # Show
    cv2.imshow("3-Way Vehicle Count (Persons shown as motorcycle)", combined_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release
for cap in caps:
    cap.release()
cv2.destroyAllWindows()
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU
# YOLO is using device: cuda:0
#
# 0: 384x640 (no detections), 24.8ms
# Speed: 4.0ms preprocess, 24.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 5.2ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 3.8ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.9ms
# Speed: 6.9ms preprocess, 20.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.2ms
# Speed: 3.6ms preprocess, 20.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 20.6ms
# Speed: 3.6ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.1ms
# ...

# %%
# for creating logic for time for green light and red light 


from ultralytics import YOLO
import cv2
import torch
import numpy as np
import time

# Check GPU
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))

# Load YOLO model
model = YOLO("yolov8n.pt")
model.to("cuda")

# Video paths
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

# ROI polygons
roi_polygons = [
    [(208, 706), (500, 49), (575, 41), (1271, 660)],
    [(261, 715), (552, 83), (656, 82), (1056, 706)],
    [(481, 718), (672, 49), (722, 49), (1142, 713)]
]

vehicle_classes = [2, 3, 5, 7]
person_class = 0

caps = [cv2.VideoCapture(path) for path in video_paths]
num_lanes = len(caps)

# Initial light state
current_lane = 0
lane_green_time = [20] * num_lanes  # default
lane_vehicle_counts = [0] * num_lanes
start_time = time.time()

while True:
    frames = []
    updated_counts = []

    for i, cap in enumerate(caps):
        ret, frame = cap.read()
        if not ret:
            break

        # YOLO detection
        results = model(frame, conf=0.3)

        polygon_pts = roi_polygons[i]
        count = 0

        for box in results[0].boxes:
            cls_id = int(box.cls)
            if cls_id in vehicle_classes or cls_id == person_class:
                x_min = box.xyxy[0][0].item()
                y_min = box.xyxy[0][1].item()
                x_max = box.xyxy[0][2].item()
                y_max = box.xyxy[0][3].item()

                center_x = (x_min + x_max) / 2
                center_y = (y_min + y_max) / 2

                inside = cv2.pointPolygonTest(np.array(polygon_pts, dtype=np.int32), (center_x, center_y), False)
                if inside >= 0:
                    count += 1

                # Draw box
                cv2.rectangle(frame, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
                if cls_id == person_class:
                    label = "motorcycle"
                else:
                    label = model.names[cls_id]
                cv2.putText(frame, label, (int(x_min), int(y_min) - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

        # Save count
        updated_counts.append(count)

        # Draw polygon
        cv2.polylines(frame, [np.array(polygon_pts, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=3)

        frames.append(frame)

    if len(frames) != num_lanes:
        break

    # Update green time logic if new
    lane_vehicle_counts = updated_counts
    for idx, v_count in enumerate(lane_vehicle_counts):
        if v_count <= 10:
            lane_green_time[idx] = 20
        elif v_count <= 30:
            lane_green_time[idx] = 30
        else:
            lane_green_time[idx] = 40

    # Check time left for current lane
    elapsed = time.time() - start_time
    time_left = lane_green_time[current_lane] - elapsed

    if time_left <= 0:
        # Move to next lane
        current_lane = (current_lane + 1) % num_lanes
        start_time = time.time()
        time_left = lane_green_time[current_lane]

    # Resize and draw lights
    target_height = 480
    target_width = 640
    display_frames = []

    # Compute total cycle time
    cycle_times = [lane_green_time[i] for i in range(num_lanes)]

    # Compute time left for each lane
    for idx, f in enumerate(frames):
        f = cv2.resize(f, (target_width, target_height))

        if idx == current_lane:
            # Current green lane
            color = (0, 255, 0)
            status_text = f"GREEN ({int(time_left)} sec)"
        else:
            # Red lane: compute how long it will take before it turns green again
            # Compute remaining green times of other lanes before it gets green again
            tmp_lane = current_lane
            tmp_time = time_left
            while tmp_lane != idx:
                tmp_lane = (tmp_lane + 1) % num_lanes
                tmp_time += lane_green_time[tmp_lane]
            color = (0, 0, 255)
            status_text = f"RED ({int(tmp_time)} sec)"

        # Draw traffic light rectangle
        cv2.rectangle(f, (10, 10), (110, 110), color, -1)
        cv2.putText(f, status_text, (10, 150),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.2, color, 3)

        # Vehicle count
        cv2.putText(f, f"Count: {lane_vehicle_counts[idx]}", (10, 200),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)

        display_frames.append(f)

    # Combine
    combined_frame = np.hstack(display_frames)

    cv2.imshow("Smart Traffic Light System", combined_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release
for cap in caps:
    cap.release()
cv2.destroyAllWindows()
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU
#
# 0: 384x640 (no detections), 21.9ms
# Speed: 3.9ms preprocess, 21.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.4ms
# Speed: 3.6ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.1ms
# Speed: 4.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 2.7ms preprocess, 20.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.7ms
# Speed: 2.9ms preprocess, 20.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 20.7ms
# Speed: 2.5ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.5ms
# ...

# %%
# for creating logic for time for green light and red light 

from ultralytics import YOLO
import cv2
import torch
import numpy as np
import time

# Check GPU
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0))

# Load YOLO model
model = YOLO("yolov8n.pt")
model.to("cuda")

# Video paths
video_paths = [
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 futa pillibhit fix 1 morning.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 3 AFTERNOON.mp4",
    r"C:\Users\ravis\Videos\VIdeo\ved\Converted_folder\100 FUTA PILLIBHIT FIX 4 EVENING.mp4"
]

# ROI polygons
roi_polygons = [
    [(208, 706), (500, 49), (575, 41), (1271, 660)],
    [(261, 715), (552, 83), (656, 82), (1056, 706)],
    [(481, 718), (672, 49), (722, 49), (1142, 713)]
]

vehicle_classes = [2, 3, 5, 7]
person_class = 0

caps = [cv2.VideoCapture(path) for path in video_paths]
num_lanes = len(caps)

# Initial light state
current_lane = 0
lane_green_time = [20] * num_lanes  # default
lane_vehicle_counts = [0] * num_lanes
start_time = time.time()

# Target sizes for each frame
target_height = 480
target_width = 640

# Output size for combined video (top row = two widths, bottom row = same width, but height = one frame height)
output_width = target_width * 2
output_height = target_height * 2

out = cv2.VideoWriter('output.avi', cv2.VideoWriter_fourcc(*'XVID'), 20, (output_width, output_height))

while True:
    frames = []
    updated_counts = []

    for i, cap in enumerate(caps):
        ret, frame = cap.read()
        if not ret:
            break

        # YOLO detection
        results = model(frame, conf=0.3)

        polygon_pts = roi_polygons[i]
        count = 0

        for box in results[0].boxes:
            cls_id = int(box.cls)
            if cls_id in vehicle_classes or cls_id == person_class:
                x_min = box.xyxy[0][0].item()
                y_min = box.xyxy[0][1].item()
                x_max = box.xyxy[0][2].item()
                y_max = box.xyxy[0][3].item()

                center_x = (x_min + x_max) / 2
                center_y = (y_min + y_max) / 2

                inside = cv2.pointPolygonTest(np.array(polygon_pts, dtype=np.int32), (center_x, center_y), False)
                if inside >= 0:
                    count += 1

                # Draw box
                cv2.rectangle(frame, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
                if cls_id == person_class:
                    label = "motorcycle"
                else:
                    label = model.names[cls_id]
                cv2.putText(frame, label, (int(x_min), int(y_min) - 5),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)

        updated_counts.append(count)
        cv2.polylines(frame, [np.array(polygon_pts, dtype=np.int32)], isClosed=True, color=(0, 255, 0), thickness=3)
        frames.append(frame)

    if len(frames) != num_lanes:
        break

    lane_vehicle_counts = updated_counts
    for idx, v_count in enumerate(lane_vehicle_counts):
        if v_count <= 10:
            lane_green_time[idx] = 20
        elif v_count <= 30:
            lane_green_time[idx] = 30
        else:
            lane_green_time[idx] = 40

    elapsed = time.time() - start_time
    time_left = lane_green_time[current_lane] - elapsed

    if time_left <= 0:
        current_lane = (current_lane + 1) % num_lanes
        start_time = time.time()
        time_left = lane_green_time[current_lane]

    display_frames = []

    for idx, f in enumerate(frames):
        f = cv2.resize(f, (target_width, target_height))

        if idx == current_lane:
            color = (0, 255, 0)
            status_text = f"GREEN ({int(time_left)} sec)"
        else:
            tmp_lane = current_lane
            tmp_time = time_left
            while tmp_lane != idx:
                tmp_lane = (tmp_lane + 1) % num_lanes
                tmp_time += lane_green_time[tmp_lane]
            color = (0, 0, 255)
            status_text = f"RED ({int(tmp_time)} sec)"

        cv2.rectangle(f, (10, 10), (110, 110), color, -1)
        cv2.putText(f, status_text, (10, 150),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.2, color, 3)
        cv2.putText(f, f"Count: {lane_vehicle_counts[idx]}", (10, 200),
                    cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)

        display_frames.append(f)

    # Arrange top row (first two), bottom row (third centered)
    top_row = np.hstack(display_frames[:2])

    bottom_frame = display_frames[2]
    bottom_width = target_width
    bottom_height = target_height

    # Create black background same width as top row
    black_background = np.zeros((bottom_height, output_width, 3), dtype=np.uint8)

    # Calculate offset to center
    x_offset = (output_width - bottom_width) // 2
    black_background[:, x_offset:x_offset + bottom_width] = bottom_frame

    # Stack rows
    combined_frame = np.vstack([top_row, black_background])

    out.write(combined_frame)
    cv2.imshow("Smart Traffic Light System", combined_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

for cap in caps:
    cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# CUDA available: True
# Device: NVIDIA GeForce RTX 4050 Laptop GPU
#
# 0: 384x640 (no detections), 24.4ms
# Speed: 3.7ms preprocess, 24.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.8ms
# Speed: 3.7ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.5ms
# Speed: 3.5ms preprocess, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.1ms
# Speed: 2.3ms preprocess, 20.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 4 cars, 20.5ms
# Speed: 3.7ms preprocess, 20.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.2ms
# ...
